# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/k0/18zjr45n3_q8w580qhbvms600000gn/T/pip-req-build-icipi9hv
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/k0/18zjr45n3_q8w580qhbvms600000gn/T/pip-req-build-icipi9hv
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.3.2)
# Requirement already satisfied: matplotlib in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (3.10.6)
# Requirement already satisfied: scipy in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/envs/studie/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 1000   # Hidden dimensions
D_o = 20   # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o)
)

def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=1000, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=1000, out_features=1000, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=1000, out_features=20, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.439102, train error 50.53,  test loss 1.603587, test error 62.90
# Epoch     1, train loss 1.050759, train error 37.70,  test loss 1.357540, test error 51.50
# Epoch     2, train loss 0.764667, train error 27.15,  test loss 1.208627, test error 46.10
# Epoch     3, train loss 0.585533, train error 20.45,  test loss 1.206303, test error 46.10
# Epoch     4, train loss 0.494409, train error 16.85,  test loss 1.151697, test error 41.10
# Epoch     5, train loss 0.289750, train error 7.97,  test loss 1.116103, test error 38.60
# Epoch     6, train loss 0.188185, train error 4.03,  test loss 1.077802, test error 36.70
# Epoch     7, train loss 0.142516, train error 2.85,  test loss 1.153290, test error 36.10
# Epoch     8, train loss 0.103883, train error 2.45,  test loss 1.187666, test error 37.10
# Epoch     9, train loss 0.045581, train error 0.22,  test loss 1.119745, test error 33.90
# Epoch    10, train loss 0.024276, train error 0.00,  test loss 1.103765, test error 33.90
# Epoch    11, train loss 0.019201, train error 0.00,  test loss 1.124993, test error 34.70
# Epoch    12, train loss 0.016412, train error 0.00,  test loss 1.140460, test error 34.20
# Epoch    13, train loss 0.014742, train error 0.00,  test loss 1.154182, test error 34.90
# Epoch    14, train loss 0.013440, train error 0.00,  test loss 1.164289, test error 34.80
# Epoch    15, train loss 0.012365, train error 0.00,  test loss 1.165828, test error 34.90
# Epoch    16, train loss 0.011358, train error 0.00,  test loss 1.181883, test error 35.00
# Epoch    17, train loss 0.010623, train error 0.00,  test loss 1.188572, test error 34.30
# Epoch    18, train loss 0.009941, train error 0.00,  test loss 1.196322, test error 35.00
# Epoch    19, train loss 0.009328, train error 0.00,  test loss 1.204942, test error 34.90
# Epoch    20, train loss 0.009015, train error 0.00,  test loss 1.206477, test error 34.80
# Epoch    21, train loss 0.008766, train error 0.00,  test loss 1.211429, test error 35.10
# Epoch    22, train loss 0.008523, train error 0.00,  test loss 1.213155, test error 34.80
# Epoch    23, train loss 0.008313, train error 0.00,  test loss 1.213852, test error 34.70
# Epoch    24, train loss 0.008103, train error 0.00,  test loss 1.219458, test error 34.80
# Epoch    25, train loss 0.007915, train error 0.00,  test loss 1.222562, test error 34.80
# Epoch    26, train loss 0.007724, train error 0.00,  test loss 1.225066, test error 34.30
# Epoch    27, train loss 0.007536, train error 0.00,  test loss 1.227640, test error 34.80
# Epoch    28, train loss 0.007371, train error 0.00,  test loss 1.228015, test error 34.90
# Epoch    29, train loss 0.007194, train error 0.00,  test loss 1.234331, test error 34.70
# Epoch    30, train loss 0.007107, train error 0.00,  test loss 1.233608, test error 34.70
# Epoch    31, train loss 0.007030, train error 0.00,  test loss 1.235116, test error 34.70
# Epoch    32, train loss 0.006953, train error 0.00,  test loss 1.235810, test error 34.70
# Epoch    33, train loss 0.006879, train error 0.00,  test loss 1.237729, test error 34.70
# Epoch    34, train loss 0.006807, train error 0.00,  test loss 1.237577, test error 34.70
# Epoch    35, train loss 0.006736, train error 0.00,  test loss 1.239886, test error 34.70
# Epoch    36, train loss 0.006667, train error 0.00,  test loss 1.240926, test error 34.60
# Epoch    37, train loss 0.006598, train error 0.00,  test loss 1.242351, test error 34.70
# Epoch    38, train loss 0.006531, train error 0.00,  test loss 1.243983, test error 34.60
# Epoch    39, train loss 0.006465, train error 0.00,  test loss 1.244736, test error 34.70
# Epoch    40, train loss 0.006432, train error 0.00,  test loss 1.245285, test error 34.70
# Epoch    41, train loss 0.006399, train error 0.00,  test loss 1.245651, test error 34.60
# Epoch    42, train loss 0.006368, train error 0.00,  test loss 1.246380, test error 34.60
# Epoch    43, train loss 0.006336, train error 0.00,  test loss 1.247459, test error 34.60
# Epoch    44, train loss 0.006305, train error 0.00,  test loss 1.247506, test error 34.60
# Epoch    45, train loss 0.006275, train error 0.00,  test loss 1.247860, test error 34.60
# Epoch    46, train loss 0.006244, train error 0.00,  test loss 1.248980, test error 34.60
# Epoch    47, train loss 0.006214, train error 0.00,  test loss 1.249373, test error 34.50
# Epoch    48, train loss 0.006184, train error 0.00,  test loss 1.249968, test error 34.60
# Epoch    49, train loss 0.006154, train error 0.00,  test loss 1.250563, test error 34.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
